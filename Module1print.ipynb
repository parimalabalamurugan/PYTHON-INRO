# %%
print("hi")   
print('hi')

# %%
#ADDITION PGM

num1=10
num2=20
add=num1+num2
print(add)

# %%
#vble declaration  Space not allowed.use _
Firstname="pa"
print(Firstname)

# %%
# EXAMPLE
print("The addition of two numbers")
num1=20
print("The number1:",num1)
num2=30
print("the number2:",num2)
print("The Answer:",num1+num2)

# %%
#RUNTIME I/P
num1=int(input("enter the number1"))
num2=int(input("enter the number1"))
add=num1+num2
print("addition of two number",add)
# Out:
# enter the number1 10
# enter the number1 20
# addition of two number 30
